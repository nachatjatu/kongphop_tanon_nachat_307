# %%
# load required libraries
import os
import gzip
import xml.etree.ElementTree as ET
import pandas as pd

# %%
def flatten_item(item):
    row = {}
    for child in item:
        row[child.tag] = child.text
    return row

def xml_to_csv(root, output):
    # get all .gz files
    all_gz_files = []
    for root, _, files in os.walk(root):
        for f in files:
            if f.lower().endswith(".xml.gz"):
                all_gz_files.append(os.path.join(root, f))

    # filter out tmc files
    gz_files = [
        f for f in all_gz_files
        if "tmc" not in os.path.basename(f).lower()
    ]

    all_rows = []

    for gz_file in gz_files:
        try:
            # decompress the file and read XML
            with gzip.open(gz_file, 'rb') as f:
                xml_data = f.read()

            # parse XML 
            root = ET.fromstring(xml_data)

            # extract all <item> elements
            items = root.findall(".//channel/item")

            for item in items:
                row = flatten_item(item)
                row["source_file"] = gz_file
                all_rows.append(row)

        except Exception as e:
            print(f"❌ Error parsing {gz_file}: {e}")

    # save to CSV
    df = pd.DataFrame(all_rows)

    # filter needed columns
    df = df[df["type"].astype(int) == 3]
    df = df[["latitude", "longitude", "starttime", "description_en", "road_en"]]

    df.to_csv(output, index=False)

# %%
xml_to_csv("../raw_data/iTIC-Longdo-Traffic-events-2021", "../processed_data/2021_incidents.csv")
xml_to_csv("../raw_data/iTIC-Longdo-Traffic-events-2022", "../processed_data/2022_incidents.csv")
xml_to_csv("../raw_data/iTIC-Longdo-Traffic-events-2023-incomplete", "../processed_data/2023_incidents.csv")
# Out:
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/03/05/202103051230-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/03/17/202103172200-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/04/04/202104041900-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/04/04/202104041700-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/04/27/202104270900-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/04/16/202104160600-event.xml.gz: mismatched tag: line 9367, column 185
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/04/16/202104160730-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/04/16/202104160630-event.xml.gz: mismatched tag: line 12106, column 6
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/04/16/202104160530-event.xml.gz: mismatched tag: line 2670, column 323
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/04/30/202104302200-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/04/202105042100-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/04/202105041800-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/04/202105040430-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/04/202105041930-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/04/202105040100-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/04/202105040700-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/04/202105040000-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/05/202105051230-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/05/202105051130-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/05/202105051030-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/05/202105051100-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/05/02/202105020400-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/10/27/202110271500-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/07/05/202107051430-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/08/02/202108022300-event.xml.gz: not well-formed (invalid token): line 253, column 65
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/08/02/202108022330-event.xml.gz: not well-formed (invalid token): line 325, column 65
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/08/27/202108271300-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2021/06/15/202106150230-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2022/04/03/202204032230-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2022/02/21/202202210900-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2022/02/21/202202210930-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2022/11/11/202211111030-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2022/11/25/202211252030-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2022/10/06/202210061200-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2022/07/16/202207160700-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2022/09/11/202209110000-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2022/09/06/202209061230-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2022/08/19/202208191100-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2023-incomplete/03/29/202303291730-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2023-incomplete/03/29/202303291700-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2023-incomplete/03/29/202303291800-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2023-incomplete/03/28/202303281730-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2023-incomplete/03/15/202303150100-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2023-incomplete/05/30/202305301730-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2023-incomplete/02/23/202302232330-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2023-incomplete/07/01/202307011400-event.xml.gz: no element found: line 1, column 0
# ❌ Error parsing data/iTIC-Longdo-Traffic-events-2023-incomplete/01/13/202301132030-event.xml.gz: no element found: line 1, column 0
